# %%
import dotenv
import os

from genai.credentials import Credentials
from genai.schemas import GenerateParams
from genai.model import Model

dotenv.load_dotenv()

api_key = os.getenv("GENAI_KEY", None)
api_endpoint = os.getenv("GENAI_API", None)

creds = Credentials(api_key,api_endpoint)

params = GenerateParams(
    decoding_method="greedy",
    max_new_tokens=1000,
    min_new_tokens=1,
    stop_sequences=['"""']
).dict()

model = Model(model="bigcode/starcoder",credentials=creds, params=params)

# %%
import dotenv
import os

from ibm_watson_machine_learning.foundation_models.utils.enums import ModelTypes
from ibm_watson_machine_learning.foundation_models import Model
from ibm_watson_machine_learning.metanames import GenTextParamsMetaNames as GenParams
from ibm_watson_machine_learning.foundation_models.extensions.langchain import WatsonxLLM

dotenv.load_dotenv()

api_key = os.getenv("API_KEY", None)
project_id = os.getenv("PROJECT_ID", None)

creds = {
    "url"    : "https://us-south.ml.cloud.ibm.com",
    "apikey" : api_key
}

params = {
    GenParams.DECODING_METHOD:"greedy",
    GenParams.MAX_NEW_TOKENS:500,
    GenParams.MIN_NEW_TOKENS:15,
    GenParams.STOP_SEQUENCES: ['Human:']
}

model = Model(ModelTypes.STARCODER,creds,params,project_id)

# %%
samplein = """<messageAction>
        <business>
            <function>REG</function>
        </business>
    </messageAction>"""

sampleout = """"messageAction": {
        "business": {
            "function": "REG"
        }
    }"""

# %%
import xml.etree.ElementTree as et

tree = et.parse('input.xml')
root = tree.getroot()

# %%
soap = '''<SOAP-ENV:Envelope xmlns:SOAP-ENV="http://schemas.xmlsoap.org/soap/envelope/" xmlns:ns1="http://www.example.com/ns1">
   <SOAP-ENV:Body>
      <ns1:getData>
         <ns1:id>1</ns1:id>
      </ns1:getData>
   </SOAP-ENV:Body>
</SOAP-ENV:Envelope>'''

# %%
finaloutcome = ""

for child in root:
    childsoap = et.tostring(child)
    prompt = f'''convert this SOAP call to RESTful call:
    XML:
    {childsoap}
    RESTful:'''

    response_text = model.generate([prompt])
    for resp in response_text:
        print(resp.generated_text)
        finaloutcome += resp.generated_text
# Out:
#     {
#         "messageAction": {
#             "business": {
#                 "function": "REG"
#             }
#         }
#     }
#     """
#
#     {
#         "activityReport": {
#             "activityId": {
#                 "referenceType": "EUP"
#             },
#             "action": {
#                 "actionRequestCode": "X"
#             },
#             "activityReference": {
#                 "elementReference": {
#                     "qualifier": "OT",
#                     "number": "8"
#                 },
#                 "segmentName": "FE"
#             }
#         }
#     }
#     """
#
#     {
#         "activityReport": {
#             "activityId": {
#                 "referenceType": "EUP"
#             },
#             "action": {
#                 "actionRequestCode": "X"
#             },
#             "activityReference": {
#                 "elementReference": {
#                     "qualifier": "OT",
#                     "number": "9"
#                 },
#                 "segmentName": "FV"
#             }
#         }
#     }
#     """
#
#     {
#         "activityReport": {
#             "activityId": {
#                 "referenceType": "EUP"
#             },
#             "action": {
#                 "actionRequestCode": "X"
#             },
#             "activityReference": {
#                 "elementReference": {
#                     "qualifier": "OT",
#                     "number": "25"
#                 },
#                 "segmentName": "TK"
#             }
#         }
#     }
#     """
#
#     {
#         "activityReport": {
#             "activityId": {
#                 "referenceType": "EUP"
#             },
#             "action": {
#                 "actionRequestCode": "A"
#             },
#             "activityReference": {
#                 "elementReference": {
#                     "qualifier": "OT",
#                     "number": "26"
#                 },
#                 "segmentName": "TK"
#             }
#         }
#     }
#     """
#
#     {
#         "activityReport": {
#             "activityId": {
#                 "referenceType": "EUP"
#             },
#             "action": {
#                 "actionRequestCode": "X"
#             },
#             "activityReference": {
#                 "elementReference": {
#                     "qualifier": "OT",
#                     "number": "19"
#                 },
#                 "segmentName": "SSR"
#             }
#         }
#     }
#     """
#
#     {
#         "activityReport": {
#             "activityId": {
#                 "referenceType": "EUP"
#             },
#             "action": {
#                 "actionRequestCode": "X"
#             },
#             "activityReference": {
#                 "elementReference": {
#                     "qualifier": "OT",
#                     "number": "20"
#                 },
#                 "segmentName": "SSR"
#             }
#         }
#     }
#     """
#
#     {
#         "activityReport": {
#             "activityId": {
#                 "referenceType": "EUP"
#             },
#             "action": {
#                 "actionRequestCode": "X"
#             },
#             "activityReference": {
#                 "elementReference": {
#                     "qualifier": "OT",
#                     "number": "10"
#                 },
#                 "segmentName": "RM"
#             }
#         }
#     }
#     """
#
#     {
#         "activityReport": {
#             "activityId": {
#                 "referenceType": "EUP"
#             },
#             "action": {
#                 "actionRequestCode": "X"
#             },
#             "activityReference": {
#                 "elementReference": {
#                     "qualifier": "OT",
#                     "number": "22"
#                 },
#                 "segmentName": "RM"
#             }
#         }
#     }
#     """
#
#     {
#         "activityReport": {
#             "activityId": {
#                 "referenceType": "EUP"
#             },
#             "action": {
#                 "actionRequestCode": "X"
#             },
#             "activityReference": {
#                 "elementReference": {
#                     "qualifier": "ST",
#                     "number": "1"
#                 },
#                 "segmentName": "AIR"
#             }
#         }
#     }
#     """
#
#     {
#         "activityReport": {
#             "activityId": {
#                 "referenceType": "EUP"
#             },
#             "action": {
#                 "actionRequestCode": "X"
#             },
#             "activityReference": {
#                 "elementReference": {
#                     "qualifier": "ST",
#                     "number": "2"
#                 },
#                 "segmentName": "AIR"
#             }
#         }
#     }
#     """
#
#     {
#         "activityReport": {
#             "activityId": {
#                 "referenceType": "EUP"
#             },
#             "action": {
#                 "actionRequestCode": "X"
#             },
#             "activityReference": {
#                 "elementReference": {
#                     "qualifier": "ST",
#                     "number": "3"
#                 },
#                 "segmentName": "AIR"
#             }
#         }
#     }
#     """
#
#     {
#         "activityReport": {
#             "activityId": {
#                 "referenceType": "EUP"
#             },
#             "action": {
#                 "actionRequestCode": "X"
#             },
#             "activityReference": {
#                 "elementReference": {
#                     "qualifier": "OT",
#                     "number": "1"
#                 },
#                 "segmentName": "TST"
#             }
#         }
#     }
#     """
#
#     {
#         "activityReport": {
#             "activityId": {
#                 "referenceType": "EUP"
#             },
#             "action": {
#                 "actionRequestCode": "X"
#             },
#             "activityReference": {
#                 "elementReference": {
#                     "qualifier": "OT",
#                     "number": "16"
#                 },
#                 "segmentName": "PDS"
#             }
#         }
#     }
#     """
#
#     {
#         "activityReport": {
#             "activityId": {
#                 "referenceType": "EUP"
#             },
#             "action": {
#                 "actionRequestCode": "X"
#             },
#             "activityReference": {
#                 "elementReference": {
#                     "qualifier": "OT",
#                     "number": "17"
#                 },
#                 "segmentName": "PDL"
#             }
#         }
#     }
#     """
#
#     {
#         "activePNRimage": {
#             "amadeusId": {
#                 "reservation": {
#                     "controlNumber": "6DR3C7"
#                 }
#             },
#             "pnrHeader": {
#                 "technicalData": {
#                     "pnrPurgeDate": "091023",
#                     "number": "9"
#                 },
#                 "reservationInfo": {
#                     "reservation": {
#                         "companyId": "1A",
#                         "controlNumber": "6DR3C7",
#                         "controlType": "A",
#                         "date": "280923",
#                         "time": "0328"
#                     }
#                 },
#                 "securityInformation": {
#                     "responsibilityInformation": {
#                         "typeOfPnrElement": "RP",
#                         "agentId": "QUSU",
#                         "officeId": "HKGCX08AA",
#                         "iataCode": "13393855"
#                     },
#                     "queueingInformation": {
#                         "queueingOfficeId": "HKGCX08AA"
#                     },
#                     "secondRpInformation": {
#                         "creationOfficeId": "HKGCX08AA",
#                         "agentSignature": "0001AA",
#                         "creationDate": "280923",
#                         "creatorIataCode": "13393855",
#                         "creationTime": "0257"
#                     }
#                 },
#                 "relatedProduct": {
#                     "quantity": "1"
#                 },
#                 "creditLine": {
#                     "officeData": {
#                         "officeId": "MUC1ATKXL",
#                         "agentCode": "9001QUSU"
#                     },
#                     "receiveFrom": "TKXL AUTO XI-9001QU/NCE1A0955"
#                 },
#                 "sbrPosDetails": [
#                     {
#                         "pointOfSaleInformationType": {
#                             "pointOfSale": {
#                                 "partyCodeQualifier": "OWN"
#                             }
#                         },
#                         "sbrUserIdentification": {
#                             "originIdentification": {
#                                 "originatorId": "13393855",
#                                 "inHouseIdentification1": "HKGCX08AA"
#                             },
#                             "originatorTypeCode": "A"
#                         },
#                         "sbrSystemDetails": {
#                             "deliveringSystem": {
#                                 "companyId": "CX",
#                                 "locationId": "HKG"
#                             }
#                         },
#                         "sbrPreferences": {
#                             "userPreferences": {
#                                 "codedCountry": "HK"
#                             }
#                         }
#                     },
#                     {
#                         "pointOfSaleInformationType": {
#                             "pointOfSale": {
#                                 "partyCodeQualifier": "CRE"
#                             }
#                         },
#                         "sbrUserIdentification": {
#                             "originIdentification": {
#                                 "originatorId": "13393855",
#                                 "inHouseIdentification1": "HKGCX08AA"
#                             },
#                             "originatorTypeCode": "E"
#                         },
#                         "sbrSystemDetails": {
#                             "deliveringSystem": {
#                                 "companyId": "CX",
#                                 "locationId": "HKG"
#                             }
#                         },
#                         "sbrPreferences": {
#                             "userPreferences": {
#                                 "codedCountry": "HK"
#                             }
#                         }
#                     },
#                     {
#                         "pointOfSaleInformationType": {
#                             "pointOfSale": {
#                                 "partyCodeQualifier": "UPD"
#                             }
#                         },
#                         "sbrUserIdentification": {
#                             "originIdentification": {
#                                 "originatorId": "12345675",
#                                 "inHouseIdentification1": "NCE1A0955"
#                             },
#                             "originatorTypeCode": "A"
#                         },
#                         "sbrSystemDetails": {
#                             "deliveringSystem": {
#                                 "companyId": "1A",
#                                 "locationId": "NCE"
#                             }
#                         },
#                         "sbrPreferences": {
#                             "userPreferences": {
#                                 "codedCountry": "FR"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "travellerInfo": {
#                 "elementManagementPassenger": {
#                     "elementReference": {
#                         "qualifier": "PT",
#                         "number": "2"
#                     },
#                     "segmentName": "NM"
#                 },
#                 "passengerData": {
#                     "travellerInformation": {
#                         "traveller": {
#                             "surname": "TEST",
#                             "quantity": "1"
#                         },
#                         "passenger": {
#                             "firstName": "<NAME>",
#                             "type": "ADT"
#                         }
#                     }
#                 }
#             },
#             "dataElementsMaster": {
#                 "marker2": None,
#                 "dataElementsIn
#
#     b'{"actionRequestCode":1}'
#     """
# ---------------------------------------------------------------------------
# GenAiException                            Traceback (most recent call last)
# /Users/yingkitw/Desktop/watsonx-demo/code_assistant/soap_to_restful_conversion.ipynb Cell 6 line 1
#       <a href='vscode-notebook-cell:/Users/yingkitw/Desktop/watsonx-demo/code_assistant/soap_to_restful_conversion.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> childsoap = et.tostring(child)
#       <a href='vscode-notebook-cell:/Users/yingkitw/Desktop/watsonx-demo/code_assistant/soap_to_restful_conversion.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> prompt = f'''convert this SOAP call to RESTful call:
#       <a href='vscode-notebook-cell:/Users/yingkitw/Desktop/watsonx-demo/code_assistant/soap_to_restful_conversion.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> XML:
#       <a href='vscode-notebook-cell:/Users/yingkitw/Desktop/watsonx-demo/code_assistant/soap_to_restful_conversion.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> {childsoap}
#       <a href='vscode-notebook-cell:/Users/yingkitw/Desktop/watsonx-demo/code_assistant/soap_to_restful_conversion.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> RESTful:'''
# ---> <a href='vscode-notebook-cell:/Users/yingkitw/Desktop/watsonx-demo/code_assistant/soap_to_restful_conversion.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a> response_text = model.generate([prompt])
#      <a href='vscode-notebook-cell:/Users/yingkitw/Desktop/watsonx-demo/code_assistant/soap_to_restful_conversion.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a> for resp in response_text:
#      <a href='vscode-notebook-cell:/Users/yingkitw/Desktop/watsonx-demo/code_assistant/soap_to_restful_conversion.ipynb#W5sZmlsZQ%3D%3D?line=11'>12</a>     print(resp.generated_text)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/genai/model.py:163, in Model.generate(self, prompts, options)
#     150 def generate(self, prompts: Union[list[str], list[PromptPattern]], options: Options = None) -> list[GenerateResult]:
#     151     """The generate endpoint is the centerpiece of the GENAI alpha.
#     152     It provides a simplified and flexible, yet powerful interface to the supported
#     153     models as a service. Given a text prompt as inputs, and required parameters
#    (...)
#     161         list[GenerateResult]: A list of results
#     162     """
# --> 163     return list(self.generate_as_completed(prompts, options))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/genai/model.py:146, in Model.generate_as_completed(self, prompts, options)
#     144             raise GenAiException(response_gen)
#     145 except GenAiException as me:
# --> 146     raise me
#     147 except Exception as ex:
#     148     raise GenAiException(ex)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/genai/model.py:144, in Model.generate_as_completed(self, prompts, options)
#     142                 yield result
#     143         else:
# --> 144             raise GenAiException(response_gen)
#     145 except GenAiException as me:
#     146     raise me
#
# GenAiException: b'{"status_code":400,"error":"Bad Request","message":"Invalid argument or out of range","extensions":{"code":"INVALID_INPUT","reason":"3 INVALID_ARGUMENT: input tokens (10822) plus prefix length (0) must be < 8192"}}'
