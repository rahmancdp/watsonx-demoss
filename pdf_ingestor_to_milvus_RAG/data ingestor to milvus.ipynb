# %%
import os
import time

from pymilvus import connections
from pymilvus import FieldSchema
from pymilvus import CollectionSchema
from pymilvus import DataType
from pymilvus import Collection
from pymilvus import utility

from langchain.embeddings import HuggingFaceEmbeddings
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter

from dotenv import load_dotenv
import genai.extensions.langchain
from genai.extensions.langchain import LangChainInterface
from genai.schemas import GenerateParams
from genai import Credentials
from genai import Model
from genai import PromptPattern

from langchain.vectorstores import FAISS

# %%
load_dotenv()
api_key = os.getenv("GENAI_KEY", None)
api_endpoint = os.getenv("GENAI_API", None)
COLLECTION_NAME = os.getenv("COLLECTION_NAME", None)
EMBEDDING_DIMENSION = os.getenv("EMBEDDING_DIMENSION", None)
EMBEDDING_COUNT = os.getenv("EMBEDDING_COUNT", None)
MILVUS_HOST = os.getenv("MILVUS_HOST", None)
MILVUS_PORT = os.getenv("MILVUS_PORT", None)

# %%
chunk_size = 1000
chunk_overlap = 150
separator = "\n"

r_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
c_splitter = CharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap, separator=separator)

# %%
COLLECTION_NAME = "menu_db"
DIMENSION = 768
COUNT = 11127
MILVUS_HOST = "52.116.143.197"
MILVUS_PORT = "19530"

# %%
load_dotenv()
api_key = os.getenv("GENAI_KEY", None)
creds = Credentials(api_key)
params = GenerateParams(
    decoding_method = "greedy"
)

# %%
connections.connect(host = MILVUS_HOST, port = MILVUS_PORT)

# if utility.has_collection(COLLECTION_NAME):
#    utility.drop_collection(COLLECTION_NAME)

fields = [
    FieldSchema(name = "id", dtype = DataType.INT64, description = "Ids", is_primary = True, auto_id = False),
    FieldSchema(name = "menu", dtype = DataType.VARCHAR, description = "menu texts", max_length = 3000),
    FieldSchema(name = "embedding", dtype = DataType.FLOAT_VECTOR, description = "Embedding vectors", dim = DIMENSION)
]
schema = CollectionSchema(fields = fields, description = "menu collection")
collection = Collection(name = COLLECTION_NAME, schema = schema)

index_params = {
    "index_type": "IVF_FLAT",
    "metric_type": "L2",
    "params": {"nlist": 1024}
}
collection.create_index(field_name = "embedding", index_params = index_params)
# Out:
# Status(code=0, message=)

# %%
embeddings = HuggingFaceEmbeddings()

# %%
def loadPDF(filename):
    loader = PyPDFLoader(filename)
    pages = loader.load()

    len(pages)

    # page= pages[10]

    # page.metadata

    # print(page.page_content[:500])

    docs = r_splitter.split_documents(pages)

    print(docs[1].page_content)
    print(docs[1].metadata)
    len(docs)
    return docs

# %%
def storeToMilvus(docs):
    start = time.time()
    data = [[], [], []]
    if docs:
        for idx, text in enumerate(docs):
            data[0].append(idx)
            data[1].append(text.page_content)
            if len(text.page_content) > 768:
                tt = text.page_content[:766] + ".."
                data[2].append(embeddings.embed_query(tt))
            else:
                data[2].append(embeddings.embed_query(text.page_content))

    collection.insert(data)
    end = time.time()
    print("Duration: ", end - start)

# %%
from pathlib import Path

for path in Path('menu').rglob('*.pdf'):
    print(os.curdir + '/menu/'+ path.name)
    docs = loadPDF(os.curdir + '/menu/'+ path.name)
    storeToMilvus(docs)

# print("Number of entities: ", collection.num_entities)
# Out:
# ./menu/TMO_SM-N970U_SM-N975U_EN_UM_P_9.0_081219_FINAL.pdf
# Table ofcontents
# Features 1
# S Pen 1
# Wireless PowerShare 1
# Meet Bixby 1
# Camera 1
# Mobile continuity 1
# Cinematic infinity display 1
# Getting started 2
# Galaxy Note10 3
# Galaxy Note10+ 4
# Assemble your device 5
# Charge the battery 6
# Wireless PowerShare 7
# Accessories 8
# Start using your device 8
# Use the Setup Wizard 8
# Transfer data from an old device 9
# Lock or unlock your device 10
# i TMO_N970U_N975U_EN_UM_TN_SGO_081219_FINAL
# {'source': './menu/TMO_SM-N970U_SM-N975U_EN_UM_P_9.0_081219_FINAL.pdf', 'page': 1}
# Duration:  22.229619026184082
# ./menu/SAM_G991U_G996U_G998U_EN_UM_R_11.0_011421_FINAL_AC.pdf
# 2 Contents
# Features
# S Pen | Mobile continuity | Bixby | Biometric secur ity | Dark mode
# Getting started
# Device layout: Galaxy S21 5G | Galaxy S21+ 5G | Galaxy S21 Ultr a 5G
# Set up your device: Charge the battery | Wireless power
#  sharing
# Start using your device: Turn on your device | Use the Setup Wi
# zard | Transfer data f
# rom
# an old device | Lock or unlock y
# our device | Side key settin
# gs | Accounts | Set up voicema
# il |
# Navigation | Navigation ba
# r | Customize you
# r home screen | S Pen | Bixby | Digital wellb
# eing
# and parental controls | Always On Disp
# lay | Biometric secu
# rity | Mobile contin
# uity | Multi
# window | Edge panels | Enter text | Emergency mod
# e
# {'source': './menu/SAM_G991U_G996U_G998U_EN_UM_R_11.0_011421_FINAL_AC.pdf', 'page': 1}
# Duration:  24.71238899230957
# ./menu/VZW_SM-N981U_SM-N986U_EN_UM_Q_10.0_080720_FINAL.pdf
# Contents
# Features
# S Pen  | Mobile continuity  | Bixby  | Biometric security  | Dark mode
# Getting started
# Device layout:  Galaxy Note20 5G  | Galaxy Note20 Ultra 5G
# Set up your device : Charge the battery  | Wireless PowerShare
# Start using your device : Turn on your device  | Use the Setup Wizard  | Transfer data from
# an old device  | Lock or unlock your device  | Side key settings  | Accounts  | Set up voicemail  |
# Navigation  | Navigation bar  | Customize your home screen  | S Pen  | Samsung Daily  | Bixby  |
# Digital wellbeing and parental controls  | Always On Display  | Biometric security  | Mobile
# continuity  | Multi window  | Edge screen  | Enter text  | Emergency mode
# Customize your home screen : App icons  | Wallpaper  | Themes  | Icons  | Widgets  | Home
# screen settings  | Easy mode  | Status bar  | Notification panel
# Camera and Gallery
# Camera : Navigate the camera screen  | Configure shooting mode  | AR Zone  | Single take  |
# {'source': './menu/VZW_SM-N981U_SM-N986U_EN_UM_Q_10.0_080720_FINAL.pdf', 'page': 1}
# Duration:  20.105230808258057
# ./menu/SAM_A146_EN_UM_OS13_122822_FINAL_AC.pdf
# Contents
# Features
# Biometric security | Dark mode
# Getting started
# Device layout: Galaxy A14 5G
# Set up your device: Charge the battery
# Start using your device: Turn on your device | Use the Setup Wizard | Bring data from an
# old device | Lock or unlock your device | Side key settings | Accounts | Set up voicemail |
# Navigation | Navigation bar | Customize your home screen | Modes and Routines |
# Digital wellbeing and parental controls | Biometric security | Mobile continuity | Multi
# window | Edge panels | Enter text
# Customize your home screen: App icons | Wallpaper | Themes | Icons | Widgets | Home
# screen settings | Status bar | Notification panel | Quick settings
# Camera and Gallery
# Camera: Navigate the camera screen | Configure shooting mode | AR Zone | Record
# videos | Camera settings
# Gallery: View
#  pictures | Edit pictures | Play video | Edit video | Share pictures and
#  videos |
# {'source': './menu/SAM_A146_EN_UM_OS13_122822_FINAL_AC.pdf', 'page': 1}
# Duration:  16.17367696762085
# ./menu/SAM_T870__T878_T970_T978_EN_UM_OS12_021722_FINAL_AC_03212022.pdf
# Contents
# Features
# S Pen | Biometric security  | Dark mode
# Getting started
# Device layout: Galaxy Tab S7+ | S7+ 5G | Galaxy Tab  S7 | S7 5G
# Set up your device: Charge the battery | Accessories
# Start
#  using your device: Turn on your device | Use the
#  Setup Wizard | Bring data
#  from an
# old device | Lock or
#  unlock your device | Side key
#  settings | Accounts | Navigation |
# Navigation bar
#  | Customize your
#  home screen | S Pen
#  | Samsung Free
#  | Bixby | Digital
# wellbeing
#  and parental controls | Biometric security
#  | Mobile continuity
#  | Multi window
#  |
# Edge panels
#  | Enter text
#
# Customize your home screen: App icons | Wallpaper | Widgets | Home screen
#  settings |
# Status bar
#  | Notification panel
#  | Quick settings
#
# Camera and Gallery
# Camera: Navigate the camera screen | Configure shooting  mode | AR Zone  | Single
# take
#  | Record videos
#  | Camera settings
# {'source': './menu/SAM_T870__T878_T970_T978_EN_UM_OS12_021722_FINAL_AC_03212022.pdf', 'page': 1}
# Duration:  16.942378997802734
# ./menu/SAM_A136_EN_UM_OS11_111721_FINAL_AC.pdf
# Contents
# Features
# Biometric security | Dark  mode
# Getting started
# Device layout: Galaxy A13 5G
# Set up your device: Charge the battery
# Start using your device: Turn on your device | Use th
# e Setup Wizard | Brin
# g data from
# an old device | Lock
#  or unlock your device | Acco
# unts | Set up
#  voicemail | Navi
# gation |
# Navi
# gation bar | Cust
# omize your home screen | Digi
# tal wellbeing and parental
# controls | Biom
# etric security | Mobi
# le continuity | Mult
# i window | Edge
#  panels | Ente
# r
# text | Emer
# gency mode
# Customize your home screen: App icons | Wall
# paper | Them
# es | Icon
# s | Widg
# ets | Home
#
# screen settings | Statu
# s bar | Noti
# fication panel | Quic
# k settings
# Camera and Gallery
# Camera: Navigate the camera screen | Conf igure shooting mode | Reco rd videos |
# Came
# ra settings
# Gallery: View pictures | Edit
#  pictures | Play
#  video | Edit
#  video | Share
#  pictures and
# {'source': './menu/SAM_A136_EN_UM_OS11_111721_FINAL_AC.pdf', 'page': 1}
# Duration:  16.050825119018555
# ./menu/SAM_X710_X810_X818_X910_EN_UM_OS13_062623_FINAL_AC_07062023.pdf
# Contents
# Features
# S Pen | Bixby | Biometric security | Dark mode
# Getting started
# Device layout: Galaxy Tab S9 Ultra | Galaxy Tab S9+ | Tab S9+ 5G | Galaxy Tab S9
# Set up your device: Maintaining water and dust resistance | Charge the battery |
# Accessories
# Start using your device: Turn on your device | Use the Setup Wizard | Bring data from an
# old device | Lock or unlock your device | Side button settings | Accounts | Navigation |
# Navigation bar | Customize your home screen | S Pen | Bixby | Modes and Routines |
# Digital wellbeing and parental controls | Biometric security | Memory card | Taskbar |
# Multi window | Edge panels | Enter text
# Customize your home screen: App icons | Wallpaper | Widgets | Home screen settings |
# Status bar | Notification panel | Quick settings
# Camera and Gallery
# {'source': './menu/SAM_X710_X810_X818_X910_EN_UM_OS13_062623_FINAL_AC_07062023.pdf', 'page': 1}
# Duration:  17.605093002319336
# ./menu/SAM_F946_F731_EN_UM_OS13_072723_FINAL.pdf
# Contents
# Features
# SPen |Bixby |Biometricsecurity  |Darkmode
# Gettingstarted
# DeviceLayout: GalaxyZFold5  |Folded  |Adaptiveflexmode | GalaxyZFlip5  |Folded  |Flex
# mode
# Setupyourdevice: Maintainingwaterresistance  |Chargethebattery  |Wirelesspower
# sharing
# Startusingyourdevice: Turnonyourdevice  |UsetheSetupWizard  |Bringdatafroman
# olddevice  |Lockorunlockyourdevice  |GalaxyZFlip5Coverscreen  |Sidebutton
# settings  |Accounts  |Setupvoicemail  |Navigation  |Navigationbar  |Customizeyour
# homescreen  |SPen |Bixby |ModesandRoutines  |Digitalwellbeingandparental
# controls  |AlwaysOnDisplay  |Biometricsecurity  |Appcontinuity |Taskbar |
# Multi window  |Edgepanels  |Entertext
# Customizeyourhomescreen: Appicons  |Wallpaper  |Themes  |Icons |Widgets  |Home
# screensettings  |Easymode  |Statusbar  |Notificationpanel |Quicksettings
# CameraandGallery
# Camera: Navigatethecamerascreen  |GalaxyZFold5Camerafeatures  |GalaxyZ
# Flip5Camerafeatures  |Configureshootingmode  |ARZone  |Recordvideos  |Cover
# {'source': './menu/SAM_F946_F731_EN_UM_OS13_072723_FINAL.pdf', 'page': 1}
# Duration:  21.288687229156494
# ./menu/SAM_S901_S906_S908_EN_UM_OS12_021022_FINAL.pdf
# Contents
# Features
# SPen |Biometricsecurity  |Darkmode
# Gettingstarted
# Devicelayout: GalaxyS22Ultra |GalaxyS22+ |GalaxyS22
# Setupyourdevice: Maintainingwateranddustresistance  |Chargethebattery  |
# Wirelesspowersharing
# Startusingyourdevice: Turnonyourdevice  |UsetheSetupWizard  |Bringdatafroman
# olddevice  |Lockorunlockyourdevice  |Sidekeysettings  |Accounts  |Setupvoicemail  |
# Navigation  |Navigationbar  |Customizeyourhomescreen  |SPen |Bixby |Digital
# wellbeingandparentalcontrols  |AlwaysOnDisplay  |Biometricsecurity  |Mobile
# continuity  |Multiwindow  |Edgepanels  |Entertext  |Emergencymode
# Customizeyourhomescreen: Appicons  |Wallpaper  |Themes  |Icons |Widgets  |Home
# screensettings  |Easymode  |Statusbar  |Notificationpanel |Quicksettings
# CameraandGallery
# Camera: Navigatethecamerascreen  |Configureshootingmode  |ARZone  |Space
# Zoom |Recordvideos  |Zoom-inmic  |Camerasettings
# Gallery: Viewpictures  |Editpictures  |Playvideo  |Videobrightness  |Editvideo  |Share
# {'source': './menu/SAM_S901_S906_S908_EN_UM_OS12_021022_FINAL.pdf', 'page': 1}
# Duration:  22.717787981033325

# %% [markdown]
# #searching

# %%
collection.load()

def search(text, embeddings):
    results = collection.search(
        data = [embeddings.embed_query(text)],
        anns_field = "embedding",
        param = {"metric_type": "L2"},
        limit = 5,
        output_fields = ["menu"]
    )

    ret = []
    for hit in results[0]:
        row = []
        row.extend([hit.id, hit.score, hit.entity.get("menu")])
        ret.append(row)
    return ret

search_terms = ["samsung", "galaxy", "camera","fold","5G"]
for x in search_terms:
    print("Searching for term:", x)
    s1 = time.time()
    for result in search(x, embeddings):
        print(result)
    e1 = time.time()
    print("Search time: ", e1 - s1)
# Out:
# Searching for term: samsung
# [324, 0.7903430461883545, 'to ensure it is working properly and is safe for children to use. \nSamsung Electronics America, Inc. \nAddress: \n85 Challenger Road \nRidgefield Park \nNew Jersey 07660 \nPhone: 1-800-SAMSUNG (726-7864) \nInternet: samsung.com \n©2021 Samsung Electronics America, Inc. Samsung, Samsung Galaxy, Multi Window, \nS Pen, Samsung Health, Samsung Pay, and Smart Switch are all trademarks of \nSamsung Electronics Co., Ltd. \nOther marks are the property of their respective owners. \nManufactured under license from Dolby Laboratories. Dolby, Dolby Atmos, and the \ndouble-D symbol are trademarks of Dolby Laboratories.']
# [134, 0.8046634197235107, 'Internet\nSamsungInternetisasimple,fast,andreliablewebbrowserforyourdevice.\nExperiencemoresecureWebbrowsingfeatureswithSecretMode,BiometricWeb\nLogin,andContentsBlocker.\nAccess BookmarksR\neload webpage Add to Bookmarks\nNavigateAccess Tabs\nTIP\xa0 \xa0Visitsamsung.com/us/support/owners/app/samsung-internet formore\ninformation.Apps\n95Devices and software are constantly evolving — the illustrations you see here are for reference only.']
# [127, 0.8096720576286316, 'Q \n-0*· www.9009 le.com \nG Google Images X + \n···-\nGooglE: \n0.1 \nAballl Adv9tbsrng Bu-u How Searchworb Pm8cy T•rns Setta1g1; \nIll 0 Apps \nInternet \nSamsung Internet is a simple, fast, and reliable web browser for your device. \nExperience more secure Web browsing features with Secret Mode, Biometric Web \nLogin, and Contents Blocker. \nAccess Bookmarks\nReload w\nebpageAdd to BookmarksNavigate\nAccess Tabs\nTIP Visit samsung.com/us/support/owners/app/samsung-internet for more \ninformation. \nDevices and software are constantly evolving — the illustrations you see here are for reference only. \n85']
# [97, 0.8410434722900391, 'Apps \nInternet \nSamsung Internet is a simple, fast, and reliable web browser for your device. \nExperience more secure Web browsing features with Secret Mode, Biometric Web \nLogin, and Contents Blocker. \nAccess BookmarksAdd t\no Bookmarks\nNavigateAccess TabsRel\noad webpage\nTIP Visit samsung.com/us/support/owners/app/samsung-internet for more \ninformation. \nDevices and software are constantly evolving — the illustrations you see here are for reference only. \n64']
# [231, 0.8428062200546265, 'Samsung Knox \nSamsung Knox is Samsung’s security platform and is a mark for a Samsung device \ntested for security with enterprise use in mind. Additional licensing fee may be \nrequired. For more information about Knox, please refer to: samsung.com/us/knox . \n1\n40']
# Search time:  0.2745821475982666
# Searching for term: galaxy
# [7, 0.937961995601654, 'GalaxyZFold5\nWARNING YourSamsungdevicecontainsmagnets.Keepitawayfromcredit\ncardsanddevicesthatmaybeaffectedbymagnets.Keepyourdevicemore\nthan6in./15cmawayfrommedicaldevices.Ifyoususpectinterferencewitha\nmedicaldevice,stopusingyourSamsungdeviceandconsultyourmedical\nprovider.Gettingstarted\n6Devices and software are constantly evolving — illustrations are for reference only.']
# [11, 0.9880683422088623, 'GalaxyZFlip5\nGettingstarted\n10Devices and software are constantly evolving — illustrations are for reference only.']
# [77, 0.9885894060134888, 'GalaxyZFold5Camerafeatures\nThefollowingfeaturesareuniquetotheGalazyZFold5.\nSettings\nSwitch cameras\nCapture Z oom\nShooting modesGalleryCapture view\nCaptureand\xa0 view\nDisplaythepicturesandvideosyoucapturewhilestillusingyourcamera.Imagesare\nshownonthesidepaneluntiltheCameraappisclosed.Thisfeatureisonlyavailable\nwhenthedeviceisopen.\n◌From\nCamera,tap\n CaptureView.CameraandGallery\n56Devices and software are constantly evolving — illustrations are for reference only.']
# [104, 1.0672543048858643, '0 Apps \nGalaxy Store \nFind and download premium apps that are exclusive to Galaxy devices. A Samsung \naccount is required to download from Galaxy Store. \nGame Launcher \nAutomatically arrange all your games in one place. For more information on Game \nLauncher, visit samsung.com/us/support/owners/app/game-launcher. \nTIP If Game Launcher is not seen in the Apps list, then from Settings, tap \nAdvanced features > Game Launcher , and then tap \n . \nPENUP \nShare photos, comment on other creations, or just browse through the pages for \nsomething to add to your personal collection. This community brings together anyone \nthat uses the S Pen to draw, sketch, scribble or paint. \nSamsung Flow \nConnect your phone and tablet with Samsung Flow. You can then view notifications \nand reply to messages from your phone on your connected tablet. You can also use \nMobile hotspot to access the Internet on your tablet through your phone’s network \nconnection when other networks are not available.']
# [74, 1.0935003757476807, 'Apps \nGame Launcher \nAutomatically arrange all your games in one place. For more information on Game \nLauncher, visit samsung.com/us/support/owners/app/game-launcher . \nTIP If Game Launcher is not seen in the Apps list, then from Settings, tap \nAdvanced features > Game Launcher , and then tap \n . \nSamsung Free \nAccess live TV shows, news and articles from numerous sources, and interactive \ngames entirely free of charge. \nSamsung Global Goals \nLearn more about the Global Goals initiative and contribute towards donations that \nsupport these causes with ads from this app. \nSamsung Members \nGet more and do more from your Galaxy device. Enjoy DIY support tools and \nexclusive experiences and content — for Samsung members only. Samsung Members \nmay be preloaded on your device, or you can download and install it from Galaxy \nStore or the Google Play store. \nSmartThings \nSmartThings allows you to control, automate, and monitor your home environment']
# Search time:  0.25777101516723633
# Searching for term: camera
# [91, 0.7885135412216187, 'Camera and Gallery\nYou can capture high-quality pictures and videos using the Camera app. Images and \nvideos are stored in the  Gallery, where you can view and edit them.\nCamera\nNavigate the camera screen \xa0| Configure shooting mode \xa0| AR Zone \xa0| Single take  | Live \nfocus \xa0| Scene optimizer \xa0| Record videos \xa0| Live focus video \xa0| Zoom-in mic \xa0| Super \nSlow-mo \xa0| Super steady \xa0| Wide-angle lens  | Camera settings\nGallery\nView pictures \xa0| Edit pictures \xa0| Play video \xa0| Video enhancer \xa0| Edit video \xa0| Share pictures \nand videos \xa0| Delete pictures and videos \xa0| Group similar images  | Create a movie \xa0| Take a \nscreenshot \xa0| Screen recorderCamera andGallery\n65Devicesandsoftwareareconstantly evolving—theillustrations youseehereareforreference only.']
# [64, 0.7934865951538086, 'Apps and features\n65\nUseful features\n• Auto HDR : Take pictures with rich colours and reproduce details even in bright and dark \nareas.\n• Tracking auto-focus : Set the device to track and automatically focus on a selected \nsubject. When you select a subject on the preview screen, the device will focus on the \nsubject even if the subject is moving or you change the camera’s position.\nTracking a subject may fail in the following conditions:\n• The subject is too big or too small.\n• The subject moves excessively.\n• The subject is backlit or you are shooting in a dark place.\n• Colours or patterns on the subject and the background are the same.\n• The subject includes horizontal patterns, such as blinds.\n• The camera shakes excessively.\n• The video resolution is high.\n• When zooming in or out using the optical zoom.\n• Grid lines : Display viewfinder guides to help composition when selecting subjects.\n• Location tags : Attach a GPS location tag to the picture.\n• GPS signal strength may decrease in locations where the signal is obstructed, such as between buildings or in low-lying areas, or in poor weather conditions.\n• Your location may appear on your pictures when you upload them to the Internet. To avoid this, deactivate the location tag setting.\n• Shooting methods : Select additional shooting methods for taking a picture or recording \na video.\n• Settings to keep : Keep the last settings you used, such as the shooting mode, when you \nlaunch the camera.\n• Vibration feedback : Set the device to vibrate in certain situations, such as when you tap \nthe camera button.\n• Reset settings : Reset the camera settings.\n• Contact us : Ask questions or view frequently asked questions.\n• About Camera : View the Camera app version and legal information.\nSome features may not be available depending on the model.']
# [102, 0.8165572881698608, 'C!) \n-\n~ • I \n0 \n(■ I -\nC!) \nD a \n< @) \n® \nI\\ Camera and Gallery \n66 Record videos \nRecord smooth lifelike videos using your device. \n1. From \n Camera , swipe right or left to change the shooting mode to Video . \n2. Tap \n Record to begin recording a video. \n• To take a picture while recording, tap \n Capture . \n• To temporarily stop recording, tap \n Pause . To continue recording, tap \nResume . \n3. Tap \n Stop when you are finished recording. \nDirector’s view \nProduce videos with seamless transitions between multiple camera angles. Dual \nrecord from both front and rear cameras and enable multi-capture with Picture-in-\npicture or Split view. \n1. From \n Camera , swipe to More , and then tap Director’s view .']
# [92, 0.8175910711288452, '61 Camera and Gallery \nYou can capture high-quality pictures and videos using the Camera app. Images and \nvideos are stored in the Gallery, where you can view and edit them. \nDevices and software are constantly evolving — the illustrations you see here are for reference only. \nCamera \nNavigate the camera screen | Configure sh ooting mode | AR Zone | Scene optimi zer | \nSingle take | Space Zoom | Record video\ns | Director’s v\niew | Zoom-in mic | Camera \nsetti\nngs \nGallery \nView pictures | Edit pictur es | Play video | Video enhan cer | Edit video | Share pictu res \nand videos | Delete pict\nures and videos | | Group similar images Take a scree\nnshot | \nScreen reco\nrder']
# [53, 0.8357608318328857, 'Camera and Gallery \nYou can capture high-quality pictures and videos using the Camera app. Images and \nvideos are stored in the Gallery, where you can view and edit them. \nCamera \nNavigate the camera screen | Con figure shooting mode | Rec ord videos | Cam era \nsettings \nGallery \nView pictures | Edi t pictures | Pla y video | Edi t video | Shar e pictures and videos | \nDel\nete pictures and videos | Gro\nup similar images | Tak\ne a screenshot \nDevices and software are constantly evolving — the illustrations you see here are for reference only. \n37']
# Search time:  0.259552001953125
# Searching for term: fold
# [9, 1.243262529373169, 'Folded\n•Foldthedevicebeforeputtingitinabagorstoringit.Donotstorethedevice\nunfoldedasanotherobjectcouldscratchorpuncturethescreen.\n•Donotfoldthedevicetowardthebackside.Thedevicewillbedamaged.\n•Whenfoldingthedevice,donotplaceanyobjects,suchascards,coins,orkeys,\nontheMainscreen.Thescreenmaybedamaged.\n•YoumaynoticeacreaseatthecenteroftheMainscreen.Thisisanormal\ncharacteristicofthedevice.Gettingstarted\n8Devices and software are constantly evolving — illustrations are for reference only.']
# [13, 1.343916416168213, "Folded\n•Foldthedevicebeforeputtingitinabagorstoringit.Donotstorethedevice\nunfoldedasanotherobjectcouldscratchorpuncturethescreen.Whenfolding\nthedevice,donotplaceanyobjectsontheMainscreen.Thescreenmaybe\ndamaged.\n•WhenusingawirelesschargerorNFC,foldthedeviceandplacethecenterofthe\ndevice'sbackonthecenterofthewirelesschargerorNFCtag.\n•Donotfoldthedevicetowardthebackside.Thedevicewillbedamaged.\n•Becarefulnottodropthedeviceonthefloor,asitcoulddamagethescreenitself\northeareawherethescreenfolds.\n•YoumaynoticeacreaseatthecenteroftheMainscreen.Thisisanormal\ncharacteristicofthedevice.Gettingstarted\n12Devices and software are constantly evolving — illustrations are for reference only."]
# [46, 1.4292373657226562, '0 Go to the groce ry store \n0 Do laundry \nD Call morri \n/4 8 :T .!. II) m fJ \n17• t-, \nG El B ~ ® \n1 2 3 4 5 6 7 8 9 \nq w e r t y u 0 \na s d f g h k \n◊ z X C V b n m \n!#1 English (US) \nIll 0 V r \n0 \np \n0 \n~ \n·-· Getting started \nEnter text \nText can be entered using a keyboard or your voice. \nExpand toolbar\nDevices and software are constantly evolving — the illustrations you see here are for reference only. \n32']
# [81, 1.453914999961853, '• < \nO Go to the grocery store \n0 Do laundry \n0 Call mom \n/4 0 :T I. [fl rn @ \n17T ., \n@ @ 8 Jl, ® \n1 2 3 4 5 6 7 8 9 \nQ w E R T y u 0 \n@ • I \nA s D F G H J K \n0 z X C V B N M \n!#1 English (US) \nIll 0 V r \n0 \nI I p \n) \nL \n0 \n~ \n·-· Getting started \n54 Enter text \nText can be entered using a keyboard or your voice. \nExpand toolbar\nDevices and software are constantly evolving — the illustrations you see here are for reference only.']
# [244, 1.456828236579895, 'hand.\n\xa01. From Settings, tap \n  Advanced features  > One-handed mode .\n\xa02. Tap Use One-handed mode  to enable the feature and select one of the following \noptions:\n\xa0•Gesture : Swipe down in the center of the bottom edge of the screen.\n\xa0•Button : Tap \n  Home  two times in quick succession to reduce the display size.\n159Settings']
# Search time:  0.46660494804382324
# Searching for term: 5G
# [5, 0.9561092853546143, 'Getting started \nGalaxy S21 5G \nGalaxy S21+ 5G \nGalaxy S21 Ultra 5G \nSet up your device \nStart using your device \n4']
# [6, 1.0410869121551514, 'Getting started\nGalaxy Note20 5G\nGalaxy Note20 Ultra 5G\nSet up your device\nStart using your device\n4']
# Search time:  0.39782094955444336
